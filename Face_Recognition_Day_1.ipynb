# %% [markdown]
# <a href="https://colab.research.google.com/github/JesseObed-jesse/Face-Recognition-app-using-python/blob/main/Face_Recognition_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# **Data Types**
# *  Primitive
#   *  boolean data type
#   *  char data type
#   *  int  data type
#   *  float data type
#
#
# *  Non - Primitive
#   *  Strings
#   *  Arrays
#   *  Classes
#   *  Interface

# %%
import cv2

# %%
img = cv2.imread('1.jpg')

# %%
print(img)
# Out:
# [[[55 25  8]
#   [55 25  8]
#   [55 25  8]
#   ...
#   [56 32  4]
#   [56 32  4]
#   [56 32  4]]
#
#  [[55 25  8]
#   [55 25  8]
#   [55 25  8]
#   ...
#   [55 31  3]
#   [55 31  3]
#   [55 31  3]]
#
#  [[55 25  8]
#   [55 25  8]
#   [55 25  8]
#   ...
#   [59 34  8]
#   [59 34  8]
#   [59 34  8]]
#
#  ...
#
#  [[53 24  9]
#   [53 24  9]
#   [54 25 10]
#   ...
#   [42 19  3]
#   [42 19  3]
#   [42 19  3]]
#
#  [[50 21  6]
#   [51 22  7]
#   [53 24  9]
#   ...
#   [41 18  2]
#   [41 18  2]
#   [41 18  2]]
#
#  [[52 23  8]
#   [53 24  9]
#   [54 25 10]
#   ...
#   [40 17  1]
#   [40 17  1]
#   [40 17  1]]]

# %%
print(img.shape)
# Out:
# (376, 236, 3)

# %%
#   !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img2rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2rgb)

# %%
plt.imshow(img2rgb[:200])
plt.title("Lord the savior")
plt.show()

# %%
img_gray = cv2.imread('1.jpg',0)
plt.imshow(img_gray[:])
plt.title("Lord the savior")
plt.show()

# %%
# run in pycharm i have given in colab because it will be easy to keep all code at one place if u run u will find error

import cv2

img = cv2.imread('1.jpg')
cv2.imshow('Lord Frame', img)
cv2.waitKey(0)

# %%
# run in pycharm i have given in colab because it will be easy to keep all code at one place if u run u will find error


import cv2

img = cv2.imread('1.jpg')
cv2.imshow('Lord Frame', img)
cv2.waitKey(0)
import cv2

cap = cv2.VideoCapture(0)

while True:
flag, frame = cap.read()
if not flag:
print("Could not connect")
cv2.imshow('frame 1 ', frame)
k = cv2.waitKey(1)
if k == ord('q'):
break

cap.release()
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

image = cv2.imread('1.jpg')
plt.imshow(image)
